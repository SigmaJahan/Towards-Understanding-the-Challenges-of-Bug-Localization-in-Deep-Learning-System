# %%
#top_10, Eclipse, Firefox, Mobile for BM25
BM25_whole =  42.03, 33.64, 35.38
BM25_textually_similar =  43.26, 39.92, 48.00
BM25_textually_dissimilar  =  41.27, 26.56, 35.96

# %%
#top_10, Eclipse, Firefox, Mobile for LDA
LDA_whole =  10.50, 10.50, 7.00
LDA_textually_similar =  13.50, 8.50, 7.50
LDA_textually_dissimilar  =  11.50, 5.00, 4.50

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#write a code to visualize the results in one bar graph for the top 10, Eclipse, Firefox, Mobile for BM25 and LDA
#top_10, Eclipse, Firefox, Mobile for BM25
BM25_whole =  42.03, 33.64, 35.38
BM25_textually_similar =  46.26, 39.92, 48.00
BM25_textually_dissimilar  =  31.27, 26.56, 35.96

#top_10, Eclipse, Firefox, Mobile for LDA
LDA_whole =  10.50, 10.50, 7.00
LDA_textually_similar =  13.50, 8.50, 7.50
LDA_textually_dissimilar  =  11.50, 5.00, 4.50

# data to plot
n_groups = 3
BM25_whole = (42.03, 33.64, 35.38)
BM25_textually_similar = (46.26, 39.92, 48.00)
BM25_textually_dissimilar = (31.27, 26.56, 35.96)

# create plot
fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.15
opacity = 0.8

rects1 = plt.bar(index, BM25_whole, bar_width,
alpha=opacity,
color='darkred',
label='BM25_whole_dataset')

rects2 = plt.bar(index + bar_width, BM25_textually_similar, bar_width,
alpha=opacity,
color='coral',
label='BM25_textually_similar')

rects3 = plt.bar(index + bar_width*2, BM25_textually_dissimilar, bar_width,
alpha=opacity,
color='peachpuff',
label='BM25_textually_dissimilar')

plt.ylabel('Recall-Rate@10%')
plt.xticks(index + bar_width, ('Eclipse', 'Firefox', 'Mobile'))
plt.legend()

plt.tight_layout()
plt.show()

# %%
import math

from matplotlib.patches import Rectangle
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

def plot_colortable(colors, *, ncols=4, sort_colors=True):

    cell_width = 212
    cell_height = 22
    swatch_width = 48
    margin = 12

    # Sort colors by hue, saturation, value and name.
    if sort_colors is True:
        names = sorted(
            colors, key=lambda c: tuple(mcolors.rgb_to_hsv(mcolors.to_rgb(c))))
    else:
        names = list(colors)

    n = len(names)
    nrows = math.ceil(n / ncols)

    width = cell_width * 4 + 2 * margin
    height = cell_height * nrows + 2 * margin
    dpi = 72

    fig, ax = plt.subplots(figsize=(width / dpi, height / dpi), dpi=dpi)
    fig.subplots_adjust(margin/width, margin/height,
                        (width-margin)/width, (height-margin)/height)
    ax.set_xlim(0, cell_width * 4)
    ax.set_ylim(cell_height * (nrows-0.5), -cell_height/2.)
    ax.yaxis.set_visible(False)
    ax.xaxis.set_visible(False)
    ax.set_axis_off()

    for i, name in enumerate(names):
        row = i % nrows
        col = i // nrows
        y = row * cell_height

        swatch_start_x = cell_width * col
        text_pos_x = cell_width * col + swatch_width + 7

        ax.text(text_pos_x, y, name, fontsize=14,
                horizontalalignment='left',
                verticalalignment='center')

        ax.add_patch(
            Rectangle(xy=(swatch_start_x, y-9), width=swatch_width,
                      height=18, facecolor=colors[name], edgecolor='0.7')
        )

    return fig

# %%
plot_colortable(mcolors.CSS4_COLORS)
plt.show()

# %%
#write a code to visualize the results in one bar graph for the top 10, Eclipse, Firefox, Mobile for BM25 and LDA

#top_10, Eclipse, Firefox, Mobile for LDA
LDA_whole =  10.50, 10.50, 7.00
LDA_textually_similar =  13.50, 8.50, 7.50
LDA_textually_dissimilar  =  11.50, 5.00, 4.50

# data to plot
n_groups = 3
LDA_whole =  (10.50, 10.50, 7.00)
LDA_textually_similar =  (13.50, 8.50, 7.50)
LDA_textually_dissimilar  =  (11.50, 5.00, 4.50)

# create plot
fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.15
opacity = 0.8

rects1 = plt.bar(index, BM25_whole, bar_width,
alpha=opacity,
color='darkgoldenrod',
label='LDA+GloVe_whole_dataset')

rects2 = plt.bar(index + bar_width, BM25_textually_similar, bar_width,
alpha=opacity,
color='gold',
label='LDA+GloVe_textually_similar')

rects3 = plt.bar(index + bar_width*2, BM25_textually_dissimilar, bar_width,
alpha=opacity,
color='khaki',
label='LDA+GloVe_textually_dissimilar')

plt.ylabel('Recall-Rate@10%')
plt.xticks(index + bar_width, ('Eclipse', 'Firefox', 'Mobile'))
plt.legend()
plt.tight_layout()
plt.show()

# %%
#pretrained word embeddings
dl_whole = 61.41, 64.70, 84.80
dl_textually_similar =  56.31, 66.44, 63.96
dl_textually_dissimilar  =  46.74, 57.06, 60.99

# data to plot
n_groups = 3
dl_whole =  (61.41, 64.70, 84.80)
dl_textually_similar =  (56.31, 66.44, 63.96)
dl_textually_dissimilar  =  (46.74, 57.06, 60.99)

# create plot
fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.15
opacity = 0.8

rects1 = plt.bar(index, dl_whole, bar_width,
alpha=opacity,
color='darkgreen',
label='DL_test_dataset')

rects2 = plt.bar(index + bar_width, dl_textually_similar, bar_width,
alpha=opacity,
color='limegreen',
label='DL_textually_similar')

rects3 = plt.bar(index + bar_width*2, dl_textually_dissimilar, bar_width,
alpha=opacity,
color='lightgreen',
label='DL_textually_dissimilar')

plt.ylabel('AUC Score (%)')
plt.xticks(index + bar_width, ('Eclipse', 'Firefox', 'Mobile'))
plt.legend()
plt.tight_layout()
plt.show()

# %%
#domain_specific word embeddings
# data to plot
n_groups = 3
dl_textually_similar =  (56.31, 56.03, 64.98)
dl_textually_dissimilar  =  (53.54, 55.16, 62.25)

# create plot
fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.15
opacity = 0.8

#create a graph for domain_specific word embeddings
rects1 = plt.bar(index + bar_width, dl_textually_similar, bar_width,
alpha=opacity,
color='blue',
label='Domain_specific_textually_similar')

rects2 = plt.bar(index + bar_width*2, dl_textually_dissimilar, bar_width,
alpha=opacity,
color='skyblue',
label='Domain_specific_textually_dissimilar')

plt.ylabel('AUC Score (%)')
plt.xticks(index + bar_width, ('Eclipse', 'Firefox', 'Mobile'))
plt.legend()
plt.tight_layout()
plt.show()

# %%
1== "Existing techniques have poor performance in detecting textually dissimilar duplicate bug reports"
2 == "Identifying textually dissimilar duplicates is challenging due to missing important components, such as steps to reproduce"
3== "Deep learning-based models have better performance than IR and Topic Modeling for detecting textually dissimilar duplicates"
4 == "Domain-specific embedding for duplicate bug report detection provided mixed results"


#visualize the texts in a word cloud
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
import pandas as pd

#read the file
df=pd.read_csv("C:/Users/HP/
# Out:
# False
